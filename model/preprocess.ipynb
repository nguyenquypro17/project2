# %%
import yaml, os

dataset_path = "/Users/ducquynguyen/Desktop/tài liệu đại học(landscape+long edge)/kì 2 năm 3/project 2/Large-License-Plate-Detection-Dataset"

data = {
    "path": dataset_path,
    "train": "images/train",
    "val": "images/val",
    "test": "images/test",
    "nc": 1,
    "names": ["license_plate"]
}

with open(f"{dataset_path}/data.yaml", "w") as f:
    yaml.dump(data, f, default_flow_style=False)

print("Created data.yaml")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 12
#       1 import yaml, os
#       3 data = {
#       4     "path": os.path.abspath("/Users/ducquynguyen/Desktop/tài liệu đại học(landscape+long edge)/kì 2 năm 3/project 2/Large-License-Plate-Detection-Dataset"),
#       5     "train": "images/train",
#    (...)      9     "names": ["license_plate"]
#      10 }
# ---> 12 with open("Large-License-Plate-Detection-Dataset/data.yaml", "w") as f:
#      13     yaml.dump(data, f, default_flow_style=False)
#      15 print("Created data.yaml")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/IPython/core/interactiveshell.py:343, in _modified_open(file, *args, **kwargs)
#     336 if file in {0, 1, 2}:
#     337     raise ValueError(
#     338         f"IPython won't let you open fd={file} by default "
#     339         "as it is likely to crash IPython. If you know what you are doing, "
#     340         "you can use builtins' open."
#     341     )
# --> 343 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Large-License-Plate-Detection-Dataset/data.yaml'
